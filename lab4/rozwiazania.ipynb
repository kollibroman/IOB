# %%
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: jupyter in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from -r requirements.txt (line 1)) (1.1.1)
# Requirement already satisfied: matplotlib in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from -r requirements.txt (line 2)) (3.10.9)
# Requirement already satisfied: numpy in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from -r requirements.txt (line 3)) (2.4.5)
# Requirement already satisfied: opencv-python in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from -r requirements.txt (line 4)) (4.13.0.92)
# Requirement already satisfied: scipy in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from -r requirements.txt (line 5)) (1.17.1)
# Requirement already satisfied: notebook in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from jupyter->-r requirements.txt (line 1)) (7.5.6)
# Requirement already satisfied: jupyter-console in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from jupyter->-r requirements.txt (line 1)) (6.6.3)
# Requirement already satisfied: nbconvert in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from jupyter->-r requirements.txt (line 1)) (7.17.1)
# Requirement already satisfied: ipykernel in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from jupyter->-r requirements.txt (line 1)) (7.2.0)
# Requirement already satisfied: ipywidgets in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from jupyter->-r requirements.txt (line 1)) (8.1.8)
# Requirement already satisfied: jupyterlab in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from jupyter->-r requirements.txt (line 1)) (4.5.7)
# Requirement already satisfied: contourpy>=1.0.1 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from matplotlib->-r requirements.txt (line 2)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from matplotlib->-r requirements.txt (line 2)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from matplotlib->-r requirements.txt (line 2)) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from matplotlib->-r requirements.txt (line 2)) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from matplotlib->-r requirements.txt (line 2)) (26.2)
# Requirement already satisfied: pillow>=8 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from matplotlib->-r requirements.txt (line 2)) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from matplotlib->-r requirements.txt (line 2)) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from matplotlib->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from python-dateutil>=2.7->matplotlib->-r requirements.txt (line 2)) (1.17.0)
# Requirement already satisfied: comm>=0.1.1 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (1.8.20)
# Requirement already satisfied: ipython>=7.23.1 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (9.13.0)
# Requirement already satisfied: jupyter-client>=8.8.0 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (8.8.0)
# Requirement already satisfied: jupyter-core!=6.0.*,>=5.1 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (0.2.2)
# Requirement already satisfied: nest-asyncio>=1.4 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (7.2.2)
# Requirement already satisfied: pyzmq>=25 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (27.1.0)
# Requirement already satisfied: tornado>=6.4.1 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (6.5.5)
# Requirement already satisfied: traitlets>=5.4.0 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (5.15.0)
# Requirement already satisfied: decorator>=5.1.0 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (5.3.0)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (0.20.0)
# Requirement already satisfied: pexpect>4.6 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (3.0.52)
# Requirement already satisfied: pygments>=2.14.0 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (0.6.3)
# Requirement already satisfied: wcwidth in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from jedi>=0.18.2->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (0.8.7)
# Requirement already satisfied: platformdirs>=2.5 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from jupyter-core!=6.0.*,>=5.1->ipykernel->jupyter->-r requirements.txt (line 1)) (4.9.6)
# Requirement already satisfied: ptyprocess>=0.5 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from pexpect>4.6->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (3.0.1)
# Requirement already satisfied: pure-eval in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (0.2.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from ipywidgets->jupyter->-r requirements.txt (line 1)) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from ipywidgets->jupyter->-r requirements.txt (line 1)) (3.0.16)
# Requirement already satisfied: async-lru>=1.0.0 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 1)) (2.3.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 1)) (0.28.1)
# Requirement already satisfied: jinja2>=3.0.3 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 1)) (3.1.6)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 1)) (2.3.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 1)) (2.18.2)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 1)) (2.28.0)
# Requirement already satisfied: notebook-shim>=0.2 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 1)) (0.2.4)
# Requirement already satisfied: setuptools>=41.1.0 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 1)) (82.0.1)
# Requirement already satisfied: anyio in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (4.13.0)
# Requirement already satisfied: certifi in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (1.0.9)
# Requirement already satisfied: idna in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (3.15)
# Requirement already satisfied: h11>=0.16 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (0.16.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (0.12.1)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (0.5.4)
# Requirement already satisfied: nbformat>=5.3.0 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (5.10.4)
# Requirement already satisfied: prometheus-client>=0.9 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (0.25.0)
# Requirement already satisfied: send2trash>=1.8.2 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (1.9.0)
# Requirement already satisfied: babel>=2.10 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (2.18.0)
# Requirement already satisfied: json5>=0.9.0 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (0.14.0)
# Requirement already satisfied: jsonschema>=4.18.0 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (4.26.0)
# Requirement already satisfied: requests>=2.31 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (2.34.2)
# Requirement already satisfied: argon2-cffi-bindings in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (25.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from jinja2>=3.0.3->jupyterlab->jupyter->-r requirements.txt (line 1)) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (0.30.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (4.1.0)
# Requirement already satisfied: pyyaml>=5.3 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (6.0.3)
# Requirement already satisfied: rfc3339-validator in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (0.1.1)
# Requirement already satisfied: fqdn in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (1.5.1)
# Requirement already satisfied: isoduration in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (3.1.1)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (1.1.0)
# Requirement already satisfied: uri-template in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (25.10.0)
# Requirement already satisfied: beautifulsoup4 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from nbconvert->jupyter->-r requirements.txt (line 1)) (4.14.3)
# Requirement already satisfied: bleach!=5.0.0 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->-r requirements.txt (line 1)) (6.3.0)
# Requirement already satisfied: defusedxml in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from nbconvert->jupyter->-r requirements.txt (line 1)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from nbconvert->jupyter->-r requirements.txt (line 1)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from nbconvert->jupyter->-r requirements.txt (line 1)) (3.2.1)
# Requirement already satisfied: nbclient>=0.5.0 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from nbconvert->jupyter->-r requirements.txt (line 1)) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from nbconvert->jupyter->-r requirements.txt (line 1)) (1.5.1)
# Requirement already satisfied: webencodings in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter->-r requirements.txt (line 1)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->-r requirements.txt (line 1)) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (2.21.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (2.7.0)
# Requirement already satisfied: lark>=1.2.2 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: cffi>=2.0.0b1 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (2.0.0)
# Requirement already satisfied: pycparser in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from cffi>=2.0.0b1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (3.0)
# Requirement already satisfied: soupsieve>=1.6.1 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from beautifulsoup4->nbconvert->jupyter->-r requirements.txt (line 1)) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from beautifulsoup4->nbconvert->jupyter->-r requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: arrow>=0.15.0 in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (1.4.0)
# Requirement already satisfied: tzdata in /home/kollibroman/Studia/IOB/.venv/lib/python3.14/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (2026.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
from matplotlib import pyplot
import numpy
from scipy.fftpack import dct
from scipy.fftpack import idct
import struct
import zlib

# %% [markdown]
# # Zadanie 1

# %%
#
# PPM file header
#
ppm_ascii_header = "P3\n3 1\n255\n"
ppm_binary_header = "P6\n3 1\n255\n"

#
# Image data
#
image =  numpy.array([[255, 0, 0, 255, 255, 255, 0, 0, 255]], dtype=numpy.uint8)

#
# Save the PPM image as an ASCII file
#
with open('lab4-ascii.ppm', 'w') as fh:
    fh.write(ppm_ascii_header)
    image.tofile(fh, sep=' ')
    fh.write('\n')

#
# Save the PPM image as a binary file
#
with open('lab4-binary.ppm', 'wb') as fh:
    fh.write(bytearray(ppm_binary_header, 'ascii'))
    image.tofile(fh)

# %%
#
# Display image
#
image_from_file = cv2.imread('lab4-ascii.ppm')
pyplot.imshow(cv2.cvtColor(image_from_file, cv2.COLOR_BGR2RGB))

# %%
#
# Display image
#
image_from_file = cv2.imread('lab4-binary.ppm')
pyplot.imshow(cv2.cvtColor(image_from_file, cv2.COLOR_BGR2RGB))

# %% [markdown]
# # Zadanie 2

# %%
colors = [
    [0,   0,   0],   
    [0,   0, 255],  
    [0, 255, 255],   
    [0, 255,   0],  
    [255, 255, 0], 
    [255,   0, 0], 
    [255,   0, 255],
    [255, 255, 255] 
]

segments = 7              
width_per_segment = 100   
height = 100          

width = segments * width_per_segment

gradient_row = []
for i in range(segments):
    start_color = colors[i]
    end_color = colors[i+1]
    
    segment = numpy.linspace(start_color, end_color, width_per_segment, endpoint=False)
    gradient_row.append(segment)

gradient_row = numpy.concatenate(gradient_row, axis=0)

image = numpy.tile(gradient_row, (height, 1, 1)).astype(np.uint8)

ppm_header = f"P6\n{width} {height}\n255\n"

with open('lab4-rainbow.ppm', 'wb') as fh:
    fh.write(ppm_header.encode('ascii'))
    image.tofile(fh)

# %%
#
# Display image
#
image_from_file = cv2.imread('lab4-rainbow.ppm')
pyplot.imshow(cv2.cvtColor(image_from_file, cv2.COLOR_BGR2RGB))

# %% [markdown]
# # Zadanie 3

# %%
colors = [
    [0,   0,   0],   
    [0,   0, 255],  
    [0, 255, 255],   
    [0, 255,   0],  
    [255, 255, 0], 
    [255,   0, 0], 
    [255,   0, 255],
    [255, 255, 255] 
]

segments = 7              
width_per_segment = 100   
height = 100          

width = segments * width_per_segment

gradient_row = []
for i in range(segments):
    start_color = colors[i]
    end_color = colors[i+1]
    
    segment = numpy.linspace(start_color, end_color, width_per_segment, endpoint=False)
    gradient_row.append(segment)

gradient_row = numpy.concatenate(gradient_row, axis=0)

image = numpy.tile(gradient_row, (height, 1, 1)).astype(np.uint8)

#
# Construct signature
#
png_file_signature = b'\x89PNG\r\n\x1a\n'

#
# Construct header
#
header_id = b'IHDR'
header_content = struct.pack('!IIBBBBB', width, height, 8, 2, 0, 0, 0)  
header_size = struct.pack('!I', len(header_content))
header_crc = struct.pack('!I', zlib.crc32(header_id + header_content))
png_file_header = header_size + header_id + header_content + header_crc

image_data = zlib.compress(b''.join([b'\x00' + bytes(row) for row in image]))

#
# Construct data
#
data_id = b'IDAT'
data_content = image_data
data_size = struct.pack('!I', len(data_content))
data_crc = struct.pack('!I', zlib.crc32(data_id + data_content))
png_file_data = data_size + data_id + data_content + data_crc

#
# Consruct end
#
end_id = b'IEND'
end_content = b''
end_size = struct.pack('!I', len(end_content))
end_crc = struct.pack('!I', zlib.crc32(end_id + end_content))
png_file_end = end_size + end_id + end_content + end_crc

#
# Save the PNG image as a binary file
#
with open('lab4.png', 'wb') as fh:
    fh.write(png_file_signature)
    fh.write(png_file_header)
    fh.write(png_file_data)
    fh.write(png_file_end)

# %%
#
# Display image
#
image_from_file = cv2.imread('lab4.png')
pyplot.imshow(cv2.cvtColor(image_from_file, cv2.COLOR_BGR2RGB))

# %% [markdown]
# # Funkcje pomocnicze do zadań 4 i 5

# %%
#
# 2d Discrete Cosinus Transform
#
def dct2(array):
    return dct(dct(array, axis=0, norm='ortho'), axis=1, norm='ortho')


def idct2(array):
    return idct(idct(array, axis=0, norm='ortho'), axis=1, norm='ortho')


#
# Calculate quantisation matrices
#
# Based on: https://www.hdm-stuttgart.de/~maucher/Python/MMCodecs/html/jpegUpToQuant.html
#           #step-3-and-4-discrete-cosinus-transform-and-quantisation
#
_QY = numpy.array([[16, 11, 10, 16, 24, 40, 51, 61],
                   [12, 12, 14, 19, 26, 48, 60, 55],
                   [14, 13, 16, 24, 40, 57, 69, 56],
                   [14, 17, 22, 29, 51, 87, 80, 62],
                   [18, 22, 37, 56, 68, 109, 103, 77],
                   [24, 35, 55, 64, 81, 104, 113, 92],
                   [49, 64, 78, 87, 103, 121, 120, 101],
                   [72, 92, 95, 98, 112, 100, 103, 99]])

_QC = numpy.array([[17, 18, 24, 47, 99, 99, 99, 99],
                   [18, 21, 26, 66, 99, 99, 99, 99],
                   [24, 26, 56, 99, 99, 99, 99, 99],
                   [47, 66, 99, 99, 99, 99, 99, 99],
                   [99, 99, 99, 99, 99, 99, 99, 99],
                   [99, 99, 99, 99, 99, 99, 99, 99],
                   [99, 99, 99, 99, 99, 99, 99, 99],
                   [99, 99, 99, 99, 99, 99, 99, 99]])


def _scale(QF):
    if QF < 50 and QF >= 1:
        scale = numpy.floor(5000 / QF)
    elif QF < 100:
        scale = 200 - 2 * QF
    else:
        raise ValueError('Quality Factor must be in the range [1..99]')

    scale = scale / 100.0
    return scale


def QY(QF=85):
    return _QY * _scale(QF)


def QC(QF=85):
    return _QC * _scale(QF)

# %% [markdown]
# # Zadania 4 i 5

# %%
#
# 0. Image data
#
# TODO: implement (zad. 4)

#
# 1. Convert RGB to YCbCr
#
# TODO: implement (zad. 4)

#
# 2. Downsampling on Cb and Cr channels
#
# TODO: implement (zad. 4)

#
# 3. Produce 8x8 blocks
#
# TODO: implement (zad. 4)

#
# 4. Calculate DCT on each block
#
# TODO: implement (zad. 5)

#
# 5. Divide each block by quantisation matrix
#
# TODO: implement (zad. 5)

#
# 6. Round values in each block to integers
#
# TODO: implement (zad. 5)

#
# 7. Zig Zag
#
# TODO: implement (zad. 4)

#
# 8. Flatten, concatenate, compress and calculate the size -- how many bytes?
#
# TODO: implement (zad. 4)

#
# 7'. Undo Zig Zag
#
# We can skip it in this exercise! We did Zig Zag only for analysis in step 8.
# You can continue with result from step 6. instead of implementing undo here.
#

#
# 6'. Nothing to do here   ¯\_(ツ)_/¯
#
# No conversion is really needed here, just proceed to the next step.
#

#
# 5'. Reverse division by quantisation matrix -- multiply
#
# TODO: implement (zad. 5)

#
# 4'. Reverse DCT
#
# TODO: implement (zad. 5)

#
# 3'. Combine 8x8 blocks to original image
#
# TODO: implement (zad. 4)

#
# 2'. Upsampling on Cb and Cr channels
#
# TODO: implement (zad. 4)

#
# 1'. Convert YCbCr to RGB
#
# TODO: implement (zad. 4)

#
# 0'. Save the decoded image -- as PPM or PNG
#
# TODO: implement (zad. 4)

# %%
#
# Display image
#
image_from_file = cv2.imread('lab4-po-kompresji-i-dekompresji-jpeg.png')
pyplot.imshow(cv2.cvtColor(image_from_file, cv2.COLOR_BGR2RGB))

# %% [markdown]
# # Obserwacje z zadań 4 i 5
